# %%
#import relevant packages used in this script

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from datetime import datetime
# create action chain object
action = ActionChains(driver)
import pandas as pd
import statistics
import csv
from time import sleep
import math
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\verbr\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\verbr\AppData\Local\Temp/ipykernel_27108/1839819035.py:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
driver.get("https://www.carrefourqatar.com/mafqat/en/c/FQAT1510000")
driver.maximize_window()
sleep(5)

# %%
total_products = driver.find_element(By.XPATH, '//*[@id="__next"]/div[3]/div/div[3]/div[2]/div[1]/div[2]/div/div/p').text
total_products = total_products.split()
total_products = total_products[0]
total_products = int(total_products)
print(total_products)
# Out:
# 194

# %%
new_element = driver.find_element(By.CSS_SELECTOR,'#__next > div.css-qo9h12 > div > div.css-4jlmt > div.css-aa17wd > div.css-1hbp62g > button')
action.move_to_element(new_element).click().perform()
sleep(5)

element = driver.find_element(By.CSS_SELECTOR, '#__next > div.css-vurnku > p > div > div.css-dum3it > svg')
element.click()
sleep(2)

# %%
def scroll_page(retailer):    
    
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    scroll_range = 0
    num_products_view_2 = 0
    number = 0 
    #create a scroller that scrolls the_range amount of times.     
    for _ in range(200):
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of products in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"class": "css-c3bgig"})))
        print(num_products_view_1)
        
        #create attributes the_name_id, the_price_id, the_brand_id and the_volume_id
        if num_products_view_1 > num_products_view_2:
            for counter in range(num_products_view_2, num_products_view_1):
                
                the_name_id = soup.find_all(attrs={"class": "css-c3bgig"})[counter].find_all(attrs={"class": "css-1nhiovu"})[0].find_all("a")[0].text
                print(the_name_id)
                try: 
                    the_price_id = soup.find_all(attrs={"class": "css-c3bgig"})[counter].find_all(attrs={"class": "css-iqeby6"})[0].text
                except: 
                    the_price_id = soup.find_all(attrs={"class": "css-c3bgig"})[counter].find_all(attrs={"class": "css-17fvam3"})[0].text
                
                the_brand_id = the_name_id.split()
                the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
                
                the_volume_id = soup.find_all(attrs={"class": "css-c3bgig"})[counter].find_all(attrs={"class": "css-1ueix7b"})[0].text           
            
                filename = "Carrefour_Qatar"
                fullpath = "../Output/" + str(filename) + ".csv"
                #write variables per product into csv file 
                with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                    writer = csv.writer(csv_file)
                    writer.writerow([retailer, the_brand_id, the_volume_id,the_name_id, the_price_id])
                number +=1
            scroll_range += 300
            driver.execute_script('window.scrollTo(0, ' + str(scroll_range) + ')')

        #break als er geen "next" button gevonden kan worden  
        sleep(3)
        try:
            new_element = driver.find_element(By.CSS_SELECTOR, '#__next > div.css-qo9h12 > div > div.css-4jlmt > div.css-aa17wd > div.css-1hbp62g > button')
            new_element.click()
            sleep(1)

        except:
            print('kan niet vinden')
            scroll_range += 300
            driver.execute_script('window.scrollTo(0, ' + str(scroll_range) + ')')
            
        print(number)
# 44
# 51
# Lebanese Coffee Maatouk Gourmet Blend Cardamom 450g
# Nescafe Instant Coffee Cardamom Arabiana 17g
# Starbucks Frappuccino Cookies & Cream Coffee 250ml
# Nescafe Espresso 100g
# Illy Coffee Instant Intense Taste 95g
# Illy Intenso Filter Bold Roast Ground Coffee 250g
# Illy Coffee Instant Smooth Taste 95g
# 51
# 56
# Best Café Coffee Cardamom 200g
# Tchibo Gold Selection Coffee 50g
# Lavazza Oro Aromatic Ground Coffee 250g
# Lavazza Qualita Oro Coffee Beans 250g
# Nescafe Arabiana With Saffron Flavor 3g×20
# 56
# 61
# Hamwi Cafe Mocha 500g
# Alicafe Coffee Cappuccino Caramel 20g
# Davidoff Coffee Fine Aroma 250g
# Bru Coffee Platina Pure Freeze Dried 75g
# Lebanese Coffee Maatouk Decaffeinated 200g
# 61
# 68
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 68
# 68
# kan niet vinden
# 68
# 68
# kan niet vinden
# 68
# 68
# kan niet vinden
# 68
# 72
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 72
# 76
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 76
# 84
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 84
# 84
# kan niet vinden
# 84
# 84
# kan niet vinden
# 84
# 84
# kan niet vinden
# 84
# 88
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 88
# 92
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 92
# 100
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 100
# 104
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 104
# 112
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 112
# 120
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 120
# 124
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 124
# 128
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 128
# 128
# kan niet vinden
# 128
# 128
# kan niet vinden
# 128
# 132
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 132
# 136
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 136
# 144
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 144
# 148
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 148
# 156
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 156
# 164
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 164
# 168
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 168
# 176
# Lebanese Coffee Maatouk Decaffeinated 200g
# Maxwell House Instant Coffee Intense Blend 190g
# Jim's Coffee Cappuccino Mix Powder 35g
# Starbucks Tripleshot Espresso Arabica Coffee Drink 300ml
# Carrefour Instant Coffee Mild Arabia 250g
# Nescafe Instant Coffee Taster's Choice French Roast 198g
# ABI NASR Coffee 500g
# Carrefour Bio Ground Coffee Peru Arabica 250g
# kan niet vinden
# 176
# 176
# kan niet vinden
# 176
# 176
# kan niet vinden
# 176
# 176
# kan niet vinden
# 176
# 176
# kan niet vinden
# 176
# 179
# Bin Hamwi Coffee With Cardamom 200g
# Carrefour Bio Ground Coffee Pure Arabica 250g
# Nescafe Instant Coffee Taster's Choice 100% Colombian 198g
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# kan niet vinden
# 179
# 179
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\verbr\AppData\Local\Temp/ipykernel_27108/3978941633.py", line 66, in <module>
#     scroll_page("Carrefour_Qatar")
#   File "C:\Users\verbr\AppData\Local\Temp/ipykernel_27108/3978941633.py", line 47, in scroll_page
#     sleep(3)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\verbr\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\verbr\AppData\Local\Temp/ipykernel_27108/3978941633.py", line 66, in <module>
#     scroll_page("Carrefour_Qatar")
#   File "C:\Users\verbr\AppData\Local\Temp/ipykernel_27108/3978941633.py", line 47, in scroll_page
#     sleep(3)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 755, in getmodule
#     os.path.realpath(f)] = module.__name__
#   File "C:\Users\verbr\anaconda3\lib\ntpath.py", line 647, in realpath
#     path = _getfinalpathname(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3444, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\verbr\AppData\Local\Temp/ipykernel_27108/3978941633.py", line 66, in <module>
#     scroll_page("Carrefour_Qatar")
#   File "C:\Users\verbr\AppData\Local\Temp/ipykernel_27108/3978941633.py", line 47, in scroll_page
#     sleep(3)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3364, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3461, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2947, in _run_cell
#     return runner(coro)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3172, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3383, in run_ast_nodes
#     self.showtraceback()
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2066, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1142, in structured_traceback
#     formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2064, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\verbr\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 1541, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 1499, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 709, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 752, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 721, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\verbr\anaconda3\lib\inspect.py", line 706, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\verbr\anaconda3\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
