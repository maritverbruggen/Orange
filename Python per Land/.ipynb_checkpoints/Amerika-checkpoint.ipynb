# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from datetime import datetime
from selenium.webdriver.common.keys import Keys

import pandas as pd
import statistics
import csv
from time import sleep
import math
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\verbr\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\verbr\AppData\Local\Temp/ipykernel_25592/1424107507.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
driver.get('https://www.amazon.com/s?k=coffee&i=amazonfresh&crid=17Y3UXDEFDB04&sprefix=coffee%2Camazonfresh%2C159&ref=nb_sb_noss_1')
driver.maximize_window()
element = driver.find_element(By.XPATH, '//*[@id="nav-main"]/div[1]/div/div/div[3]/span[2]/span/input')
element.click()

# %%
sleep(5)
inputElement = driver.find_element(By.CSS_SELECTOR, "#GLUXZipUpdateInput")
inputElement.send_keys('10019')
inputElement.send_keys(Keys.ENTER)
sleep(5)
element = driver.find_element(By.XPATH, '//*[@id="a-popover-2"]/div/div[2]/span')
element.click()
sleep(5)

# %%
def scroll_page(retailer):    
    
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    
    num_products_view_2 = 0
    lengte = 0 
    #create a scroller that scrolls the_range amount of times.     
    for _ in range(20):
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of products in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"class": "sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20"})))
        print(num_products_view_1)
        #create attributes the_name_id, the_price_id, the_brand_id and the_volume_id
        for counter in range(num_products_view_2, num_products_view_1):
            the_name_id = soup.find_all(attrs={"class": "sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20"})[counter].find_all(attrs={"class": "a-size-base-plus a-color-base a-text-normal"})[0].text
            print(the_name_id)
            the_price_id = soup.find_all(attrs={"class": "sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20"})[counter].find_all(attrs={"class": "a-offscreen"})[0].text
            the_brand_id = the_name_id.split()
            the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
            
            the_volume_id = the_name_id.split()
            for i in range(0,len(the_volume_id)):
                if any(ch.isdigit() for ch in the_volume_id[i])== True:
                    the_volume = the_volume_id[i:]
                    the_volume = ' '.join([str(elem) for elem in the_volume])
                    break
                else: 
                    the_volume = "no volume found"
            
            filename = "Amazon"
            fullpath = "../Output/" + str(filename) + ".csv"
            #write variables per product into csv file 
            with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                writer = csv.writer(csv_file)
                writer.writerow([retailer, the_brand_id, the_volume_id,the_name_id, the_price_id])
            lengte +=1
        print(lengte)
            
        #break als er geen "next" button gevonden kan worden  
        sleep(5)
        try:
            new_element = driver.find_element(By.LINK_TEXT, 'Next')
            new_element.click()
            sleep(1)

        except:
            print('kan niet vinden')
            break
scroll_page("Amazon")
# Out:
# 24
# Dunkin' Original Blend Medium Roast Ground Coffee, 30 Ounce
# Peet's Coffee, Dark Roast Ground Coffee - Major Dickason's Blend 18 Ounce Bag, Packaging May Vary
# Dunkin' Original Blend Medium Roast Ground Coffee, 20 Ounces
# International Delight Iced Coffee, Caramel Macchiato, 64 oz.
# International Delight Iced Coffee, Mocha, Half Gallon, 64oz
# International Delight Iced Coffee Vanilla 64 oz
# Dunkin' French Vanilla Flavored Ground Coffee, 20 Ounces
# Maxwell House 100% Colombian Medium Roast Ground Coffee (24.5 oz Canister)
# Starbucks Dark Roast Ground Coffee — Sumatra — 100% Arabica — 1 bag (12 oz.)
# Cafe Du Monde Coffee Chicory, 15 Ounce Ground
# 365 by Whole Foods Market, Coffee Vienna Roast Pacific Rim Ground Organic, 24 Ounce
# Peet's Coffee, Dark Roast Ground Coffee - Major Dickason's Blend 10.5 Ounce Bag, Packaging May Vary
# Folgers Hazelnut Flavored Ground Coffee, 11.5 Ounces
# Peet's Coffee, Dark Roast Ground Coffee - Organic French Roast 10.5 Ounce Bag, USDA Organic, Packaging May Vary
# Starbucks Medium Roast Ground Coffee — House Blend — 100% Arabica — 1 bag (12 oz.)
# Starbucks Medium Roast Ground Coffee — Pike Place Roast — 100% Arabica — 1 bag (12 oz.)
# Gevalia Colombia Medium Roast Ground Coffee (12 oz Bag)
# Caribou Coffee, Medium Roast Ground Coffee - Caribou Blend 20 Ounce Bag
# NESCAFE CLASICO Dark Roast Instant Coffee 7 Ounce ( Packaging May Vary)
# Starbucks Ground Coffee—Medium Roast Coffee—Breakfast Blend—100% Arabica—12 Ounce (Pack of 1)
# 10
# Lunchables Turkey & Cheddar Cheese Snack Kit with Crackers (3.2 oz Tray)
# Bonne Maman Cherry Preserves, 13 oz (1 count)
# Snack Pack Chocolate Fudge Pudding Cups, 4 ct
# POWERADE, Electrolyte Enhanced Sports Drinks w/ Vitamins, Fruit Punch, 20 Fl Oz (Pack of 8)
# Nestle Toll House Semi Sweet Chocolate Mini Chips, 10 Oz
# Cool Whip Original Whipped Topping (16 oz Tub)
# Edy's, Grand Chocolate Ice Cream, 1.5 qt (Frozen)
# Jimmy Dean Delights Bacon, Spinach, Onion Egg'wich, 4 Count
# Sara Lee, Oven Fresh Dutch Apple Pie, 34 oz (Frozen)
# Snack Pack Pie Pudding Cups, Chocolate and Vanilla, 33 oz (6 ct)
# 161
# kan niet vinden

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
driver.get("https://www.costco.com/coffee-sweeteners.html")
sleep(5)
driver.maximize_window()
sleep(10)

# %%
def scroll_page(retailer):    
    
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    
    import re
    #create scraping_round variable that counts the amount of times all the wines are being scraped 
    scraping_round = 1
    scroll_range = 0
    number = 0 
    #create a scroller that scrolls the_range amount of times.     
    for _ in range(10):
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of products in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"class": "col-xs-6 col-lg-4 col-xl-3 product"})))
        print(num_products_view_1)
        #create attributes the_name_id, the_price_id, the_brand_id and the_volume_id 
        for counter in range(num_products_view_1):
            the_name_id = soup.find_all(attrs={"class": "col-xs-6 col-lg-4 col-xl-3 product"})[counter].find_all(attrs={"class": "description"})[0].text
            the_name_id = the_name_id.strip()
            print(the_name_id)
            the_price_id = soup.find_all(attrs={"class": "col-xs-6 col-lg-4 col-xl-3 product"})[counter].find_all(True, {"class":  ["price", "member only"]})[0].text
            the_price_id = the_price_id.strip()
            the_brand_id = the_name_id.split()
            the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
            sep = ","
            try:
                the_volume_id = the_name_id.split(sep, 1)[1]
            except: 
                the_volume_id = "no volume available"
            print(the_volume_id)
            
            filename = "Costco"
            fullpath = "../Output/" + str(filename) + ".csv"
            with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                writer = csv.writer(csv_file)
                writer.writerow([retailer, the_brand_id, the_volume_id,the_name_id, the_price_id])
                       
            scraping_round += 1
            
            scroll_range += 200
            driver.execute_script('window.scrollTo(0, ' + str(scroll_range) + ')')
            sleep(0.2)
            number +=1 
       
        try: 
            new_element = driver.find_element(By.CLASS_NAME, 'forward')
            new_element.click()
            sleep(5)
        
        except: 
            print("no new page found")
            print(number)
            break
        
scroll_page("Costco")
# Out:
# 24
# San Francisco Bay Coffee French Roast OneCup, 100-count
#  100-count
# Kirkland Signature Coffee Organic Pacific Bold K-Cup Pod, 120-count
#  120-count
# Peet's Coffee Major Dickason's Blend K-Cup Pod, 75-count
#  75-count
# Kirkland Signature Coffee Breakfast Blend K-Cup Pod, 120-count
#  120-count
# Kirkland Signature Coffee Organic Summit Medium Roast K-Cup Pod, 120-count
#  120-count
# Tim Hortons Coffee Original Blend K-Cup Pod, 100-count
#  100-count
# The Original Donut Shop Coffee K-Cup Pod, 100-count
#  100-count
# Kirkland Signature Espresso Blend Coffee, Dark Roast, Whole Bean, 2.5 lbs
#  Dark Roast, Whole Bean, 2.5 lbs
# Starbucks French Roast, Whole Bean Coffee, 2.5 lbs
#  Whole Bean Coffee, 2.5 lbs
# Lavazza Caffé Espresso 100% Premium Arabica Coffee, Whole Bean, 2.2 lbs
#  Whole Bean, 2.2 lbs
# Kirkland Signature House Blend Coffee, Medium Roast, Whole Bean, 2.5 lbs
#  Medium Roast, Whole Bean, 2.5 lbs
# VitaCup Genius Coffee Pods, Infused w/ MCT Oil, Turmeric, Vitamins, 60-count
#  Infused w/ MCT Oil, Turmeric, Vitamins, 60-count
# Peet's Coffee Major Dickason's Blend Whole Bean, 10.5 oz Bags, 6-pack
#  10.5 oz Bags, 6-pack
# Dunkin' Donuts, Original Blend, Medium Roast, K-Cup Pods, 72ct
#  Original Blend, Medium Roast, K-Cup Pods, 72ct
# Folgers Instant Coffee Classic Roast Coffee, 16 oz
#  16 oz
# Starbucks Pike Place Medium Roast K-Cup, 72-count
#  72-count
# La Colombe Draft Latte Cold Brew Coffee, Variety Pack, 9 fl oz, 12-count
#  Variety Pack, 9 fl oz, 12-count
# Kirkland Signature 100% Colombian Coffee, Dark Roast, 3 lbs
#  Dark Roast, 3 lbs
# Pleasant Hill Farms Arabica Coffee 5 lb, 2-pack
#  2-pack
# DaVinci Classic Syrup, Hazelnut, 25.4 oz
#  Hazelnut, 25.4 oz
# Starbucks Coffee Caffè Verona Dark Roast K-Cup Pod, 72ct
#  72ct
# Kirkland Signature Colombian Supremo Coffee, Whole Bean, 3 lbs
#  Whole Bean, 3 lbs
# Connaisseur #4 Cone Coffee Filters, 400-count
#  400-count
# Dunkin’ Donuts Original Blend, 45 oz
#  45 oz
# 24
# DaVinci Classic Syrup, Almond, 25.4 oz
#  Almond, 25.4 oz
# Nescafé Clasico Instant Coffee, Dark Roast, 10.5 oz, 2-pack
#  Dark Roast, 10.5 oz, 2-pack
# Starbucks Coffee Veranda Blend Blonde Roast K-Cup Pods, 72-count
#  72-count
# Peet’s Coffee House Blend K-Cup Pod, 60-count
#  60-count
# Peet’s Coffee French Roast K-Cup Pod, 60-count
#  60-count
# Peet’s Coffee Café Domingo K-Cup Pod, 60-count
#  60-count
# Starbucks Coffee Single Origin Sumatra Dark Roast K-cup, 72-count
#  72-count
# Peet's Coffee Hazelnut Mocha K-Cup Pod, 60-count
#  60-count
# Kirkland Signature Coffee Organic House Decaf K-Cup Pod, 120-count
#  120-count
# Starbucks Coffee Decaffeinated Medium Roast House Blend K-Cup, 72 Count
#  72 Count
# Ruta Maya Decaffeinated Coffee 2.2 lb, 2-pack
#  2-pack
# Peet’s Coffee Decaf House Blend K-Cup Pod, 60-count
#  60-count
# Starbucks by Nespresso Espresso Roast Capsules, 60-count
#  60-count
# Starbucks Dark French Roast K-Cup, 72-count
#  72-count
# Tully's Coffee French Roast K-Cups Pods, 100-count
#  100-count
# Peet's Coffee Nespresso Compatible Aluminum Capsules, 80-count
#  80-count
# Starbucks by Nespresso Blonde Espresso Roast Capsules, 60 Count
#  60 Count
# Starbucks by Nespresso Decaf Espresso Roast Capsules, 60 Count
#  60 Count
# Magnum Coffee Exotics Jamaica Blue Mountain Blend Coffee, Whole Bean, 2 lbs
#  Whole Bean, 2 lbs
# Caribou Coffee Caribou Blend K-Cup Pod, 100-count
#  100-count
# Newman's Own Organics Coffee Special Blend K-Cup Pod, 100-count
#  100-count
# Starbucks by Nespresso Original Line Variety Pack Capsules, 60 Count
#  60 Count
# DaVinci Sugar Free Syrup, Vanilla, 25.4 oz
#  Vanilla, 25.4 oz
# VitaCup Slim Instant Coffee Packets, Boost Diet & Metabolism, 30-count
#  Boost Diet & Metabolism, 30-count
# 24
# Yuban Gold Coffee, Original, Medium Roast, 46 oz
#  Original, Medium Roast, 46 oz
# Nestlé Coffee-mate Liquid Creamer, Original, 180-count
#  Original, 180-count
# Kirkland Signature Organic Ethiopia Whole Bean Coffee, 2 lbs, 2-pack
#  2 lbs, 2-pack
# Kirkland Signature USDA Organic Whole Bean Blend 2 lb, 2-pack
#  2-pack
# DaVinci Classic Syrup, Strawberry, 25.4 oz
#  Strawberry, 25.4 oz
# Kirkland Signature Organic Colombian Decaf Whole Bean Coffee, 2 lbs, 2-pack
#  2 lbs, 2-pack
# Kirkland Signature Organic Sumatra Whole Bean Coffee, 2 lbs, 2-pack
#  2 lbs, 2-pack
# DaVinci Classic Syrup, Vanilla, 25.4 oz
#  Vanilla, 25.4 oz
# San Francisco French Roast Whole Bean Coffee 3 lb, 2-pack
#  2-pack
# DaVinci Classic Syrup, Raspberry, 25.4 oz
#  Raspberry, 25.4 oz
# Kirkland Signature Instant Coffee, Medium Roast, 16 oz
#  Medium Roast, 16 oz
# San Francisco Bay Organic Rainforest Blend Whole Bean Coffee 3 lbs, 2-pack
#  2-pack
# Parisi Artisan Coffee Bolivian Organic Blend Whole Bean 2 lb, 2-pack
#  2-pack
# Kirkland Signature Costa Rica Coffee 3 lb, 2-pack
#  2-pack
# Nescafé Taster's Choice Instant Coffee, House Blend, 14 oz
#  House Blend, 14 oz
# Tully's Coffee Hawaiian Blend K-Cups Packs, 100 ct
#  100 ct
# Nestlé Coffee-mate Coffee Creamer, Hazelnut, Pump Bottle, 50.7 fl oz
#  Hazelnut, Pump Bottle, 50.7 fl oz
# Kirkland Signature Whole Bean Coffee, French Roast, 2.5 lbs
#  French Roast, 2.5 lbs
# Nestlé Coffee-mate Powdered Creamer, Original, 56 oz
#  Original, 56 oz
# Starbucks VIA Instant Colombia Coffee, Medium Roast, 26-count
#  Medium Roast, 26-count
# N'Joy Powdered Creamer, Original, 16 oz, 8-count
#  Original, 16 oz, 8-count
# Kirkland Signature Sumatran Whole Bean Coffee 3 lb, 2-pack
#  2-pack
# DaVinci Gourmet Cane Sugar Syrup, 25.4 oz.
#  25.4 oz.
# Starbucks Doubleshot Espresso, Espresso & Cream, 6.5 fl oz, 12-count
#  Espresso & Cream, 6.5 fl oz, 12-count
# 24
# DaVinci Classic Syrup, Coconut, 25.4 oz
#  Coconut, 25.4 oz
# Peet's Coffee Big Bang Ground, 10.5 oz Bags, 6-pack
#  10.5 oz Bags, 6-pack
# Peet's Coffee Decaf Organic Terrena Ground, 10.5 bags, 6-pack
#  10.5 bags, 6-pack
# San Francisco Bay Fog Chaser Whole Bean Coffee 2 lb, 2-pack
#  2-pack
# Ruta Maya Organic Medium Roast Whole Bean Coffee 5 lb
# no volume available
# Peet's Coffee Single Origin Colombia Ground, 10.5 oz, 6-pack
#  10.5 oz, 6-pack
# Mayorga Buenos Días, USDA Organic, Light Roast, Whole Bean Coffee, 2lb, 2-pack
#  USDA Organic, Light Roast, Whole Bean Coffee, 2lb, 2-pack
# VitaCup Low Acid Perfect Coffee Pods, USDA Organic, Dark Roast, 60-count
#  USDA Organic, Dark Roast, 60-count
# Caffe D'Vita Instant Mocha Cappuccino, 4 lbs
#  4 lbs
# Lavazza Tierra Organic Whole Bean Coffee, Italian Roast, 2.2 lbs
#  Italian Roast, 2.2 lbs
# DaVinci Gourmet Sugar Free Raspberry Flavored Syrup, 25.4 oz.
#  25.4 oz.
# Copper Moon Variety Pack Whole Bean Coffee, 2 lb Bags, 4-pack
#  2 lb Bags, 4-pack
# Mayorga Organics Mayan Blend, USDA Organic, Medium Roast, Whole Bean Coffee, 2lb, 2-pack
#  USDA Organic, Medium Roast, Whole Bean Coffee, 2lb, 2-pack
# Marley Coffee Variety Pack Medium-Dark Roast Pods, 80-Count
#  80-Count
# Mayorga Café Cubano Roast, USDA Organic, Dark Roast, Whole Bean Coffee, 2lb, 2-pack
#  USDA Organic, Dark Roast, Whole Bean Coffee, 2lb, 2-pack
# Ruta Maya Organic Jiguaní Whole Bean Coffee 5 lb
# no volume available
# DaVinci Classic Syrup, Peppermint, 25.4 oz
#  Peppermint, 25.4 oz
# Kirkland Signature Rwandan Coffee 3 lb, 2-pack
#  2-pack
# Peet's Coffee Decaf Major Dickason's Ground, 10.5 oz Bags, 6-pack
#  10.5 oz Bags, 6-pack
# Mayorga Decaf Café Cubano Roast, USDA Organic, Dark Roast, Whole Bean Coffee, 2lb, 2-pack
#  USDA Organic, Dark Roast, Whole Bean Coffee, 2lb, 2-pack
# Kirkland Signature Colombian Cold Brew Coffee, 11 fl oz, 12-count
#  11 fl oz, 12-count
# DaVinci Gourmet English Toffee Flavored Syrup, 25.4 oz.
#  25.4 oz.
# Kirkland Signature Decaf House Blend Coffee, Medium Roast, Whole Bean, 2.5 lbs
#  Medium Roast, Whole Bean, 2.5 lbs
# Jose’s Vanilla Nut Whole Bean Coffee 3 lb, 2-pack
#  2-pack
# 24
# Kirkland Signature Guatemalan Coffee 3 lb, 2-pack
#  2-pack
# Peet's Coffee Organic Alameda Morning Blend Ground, 10.5 oz, 6-pack
#  10.5 oz, 6-pack
# San Francisco Bay Decaf French Roast Whole Bean Coffee 2 lb, 2-pack
#  2-pack
# San Francisco Bay Coffee Organic Rainforest Blend Ground 28oz, 2-pack
#  2-pack
# Jose’s Organic French Dark Roast Whole Bean Coffee, 3 lb, 2-pack
#  3 lb, 2-pack
# Jose’s 100% Organic Mayan Whole Bean Coffee 2.5 lb, 2-pack
#  2-pack
# Blues Brothers 440 Power Plant Organic Whole Bean Coffee 40 oz, 2-pack
#  2-pack
# Mayorga Muy Macho, USDA Organic, Muy Dark Roast, Whole Bean Coffee, 2lb, 2-pack
#  USDA Organic, Muy Dark Roast, Whole Bean Coffee, 2lb, 2-pack
# VitaCup Low Acid Perfect Ground Coffee, USDA Organic, Dark Roast, 3-Pack (10 oz each)
#  USDA Organic, Dark Roast, 3-Pack (10 oz each)
# Kirkland Signature Decaffeinated Coffee, Dark Roast, 3 lbs
#  Dark Roast, 3 lbs
# Kirkland Signature Panama Geisha Coffee, 2 lbs
#  2 lbs
# Copper Moon Variety Pack Whole Bean Coffee, 5 lb Bags, 2-pack
#  5 lb Bags, 2-pack
# Mother Earth Coffee Organic Breakfast Blend, 2 lbs, 2-pack
#  2 lbs, 2-pack
# DaVinci Gourmet Sugar Free French Vanilla Flavored Syrup, 25.4 oz.
#  25.4 oz.
# Connaisseur Coffee Filters, 700-count
#  700-count
# Ruta Maya Organic Dark Roast Coffee, 5 lbs
#  5 lbs
# San Francisco Bay Coffee Organic Sumatra Ground 2-pack (2 lb each)
# no volume available
# Kirkland Signature 100% Colombian Coffee, Dark Roast, 1.75 oz, 42-count
#  Dark Roast, 1.75 oz, 42-count
# Mother Earth Organic Medium Roast Coffee 2 lb, 2-pack
#  2-pack
# Connaisseur Commercial Basket 12 cup Filter, 1000-count
#  1000-count
# DaVinci Gourmet Irish Cream Flavored Syrup, 25.4 oz.
#  25.4 oz.
# Lee's Coffee Cafe Latte Concentrate, Original, 16 fl oz, 6-count
#  Original, 16 fl oz, 6-count
# DaVinci Gourmet Sugar Free White Chocolate Flavored Syrup, 25.4 oz.
#  25.4 oz.
# Copper Moon Dark Sky Blend, Ground Coffee, 2 lb Bags, 2-pack
#  Ground Coffee, 2 lb Bags, 2-pack
# no new page found
# 120

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
driver.get("https://shop.foodlion.com/shop/categories/101")
driver.maximize_window()
sleep(15)
element = driver.find_element(By.XPATH,'//*[@id="shopping-selector-parent-process-modal-close-click"]')
element.click()
sleep(5)

# %%
def scroll_page(retailer):    
    
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    
    number = 0
    
    #create scraping_round variable that counts the amount of times all the wines are being scraped 
    scraping_round = 1
    #create a scroller that scrolls the_range amount of times.     
    for _ in range(10):
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of products in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"class": "react-cell cell product-cell"})))
        #create attributes the_name_id, the_price_id, the_brand_id and the_volume_id 
        for counter in range(num_products_view_1):
            the_name_id = soup.find_all(attrs={"class": "react-cell cell product-cell"})[counter].find_all(attrs={"class": "cell-title-text"})[0].text
            the_price_id = soup.find_all(attrs={"class": "react-cell cell product-cell"})[counter].find_all(attrs={"data-test":  "amount"})[0].text
            the_brand_id = the_name_id.split()
            the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
            try: 
                the_volume_id = soup.find_all(attrs={"class": "react-cell cell product-cell"})[counter].find_all(attrs={"class": "cell-product-size"})[0].text
            except: 
                the_volume_id = "no volume available"
            
            filename = "Food_Lion"
            fullpath = "../Output/" + str(filename) + ".csv"
            with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                writer = csv.writer(csv_file)
                writer.writerow([retailer, the_brand_id, the_volume_id,the_name_id, the_price_id])
                       
            scraping_round += 1
            number +=1
        try:
            new_element = driver.find_element(By.CSS_SELECTOR, '#content > div > div > div.content-wrapper > div > div.cell-container > div > div > div.text-center.clearfix > nav > ul > li.pagination-next')
            new_element.click()
            sleep(5)

        except:
            print('kan geen nieuwe pagina meer vinden')
            print(number)
            break
        
scroll_page("Food_Lion")
# Out:
# kan geen nieuwe pagina meer vinden
# 425

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
driver.get("https://gopuff.com/#drinks/coffee")
driver.maximize_window()
sleep(5)
element = driver.find_element(By.CSS_SELECTOR, '#vueroot > div.consent-manager-root > div > div > div > p:nth-child(1) > div > div > button')
element.click()
sleep(3)

# %%
def scroll_page(retailer):    
    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    scroll_range = 0
    num_products_view_2 = 0
 
    
    
    for _ in range(15):
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of products in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"data-placement_type": "SHELF"})))
        if num_products_view_1 > num_products_view_2:
        #create attributes the_name_id, the_price_id, the_brand_id and the_volume_id
            for counter in range(num_products_view_2, num_products_view_1):
                the_name_id = soup.find_all(attrs={"data-placement_type": "SHELF"})[counter].find_all(attrs={"class": "gp-product-tile__text"})[0].text
                print(the_name_id)
                the_price_id = soup.find_all(attrs={"data-placement_type": "SHELF"})[counter].find_all(True,{"class": ["gp-product-tile__price gp-product-tile__price-sale", "gp-product-tile__price gp-product-tile__price_struck"]})[0].text
                the_price_id = the_price_id.replace("\n","")
                the_price_id = the_price_id.replace(" ", "")
                the_brand_id = the_name_id.split()
                try: 
                    the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
                except:
                    the_brand_id = the_brand_id[0]
                the_volume_id = the_name_id 
                the_volume_id = the_volume_id.replace("[", "")
                the_volume_id = the_volume_id.replace("]", "")
                the_volume_id = the_volume_id.replace("(", "")
                the_volume_id = the_volume_id.replace(")", "")
                the_volume_id = the_volume_id.replace("-", "\n")
                the_volume_id = the_name_id.split()  
                R = ["Btl", "Can"]
                N = [i for i in range(len(the_volume_id)) if the_volume_id[i] in R]
                if len(N) == 0: 
                    the_volume_id = the_volume_id[-1]
                else: 
                    the_volume_id = the_volume_id[N[0]-1] + " " + the_volume_id[N[0]]
                filename = "Gopuff"
                fullpath = "../Output/" + str(filename) + ".csv"
                #write variables per product into csv file 
                with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                    writer = csv.writer(csv_file)
                    writer.writerow([retailer, the_brand_id, the_volume_id,the_name_id, the_price_id])
                
    
            
            scroll_range += 1000
            driver.execute_script('window.scrollTo(0, ' + str(scroll_range) + ')')
# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
driver.get("https://www.hannaford.com/departments/beverages/coffee-tea-cocoa/coffee")
driver.maximize_window()

# %%
total_results = driver.find_element(By.XPATH, '//*[@id="main-content"]/section/section/div/div[2]').text
total_results = total_results.split()
total_results = int(total_results[0])
print(total_results)
# Out:
# 362

# %%
def scroll_page(retailer):    
    
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    
    
    #create scraping_round variable that counts the amount of times all the wines are being scraped 
    scraping_round = 1
        
    num_products_view_2 = 0
    #create a scroller that scrolls the_range amount of times.     
    for _ in range(20):
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of wines in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"data-category": "Coffee"})))
        print("nummer 1 is" + str(num_products_view_1))
        
        #create attributes the_name_id, the_price_id, the_reviews_id and the_rating id
        if num_products_view_1 > num_products_view_2:
            for counter in range(num_products_view_2, num_products_view_1):
                the_name_id = soup.find_all(attrs={"data-category": "Coffee"})[counter].find_all(attrs={"class": "productName"})[0].text
                print(the_name_id)
                try: 
                    the_price_id = soup.find_all(attrs={"data-category": "Coffee"})[counter].find_all(attrs={"class": "price item-unit-price strike-price"})[0].text
                except: 
                    the_price_id = soup.find_all(attrs={"data-category": "Coffee"})[counter].find_all(attrs={"class": "price item-unit-price"})[0].text
                the_price_id = the_price_id.replace(" ", "")
                the_price_id = the_price_id.replace("\n", "")
                the_brand_id = the_name_id.split()
                the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
                the_volume_id = soup.find_all(attrs={"data-category": "Coffee"})[counter].find_all(attrs={"class": "overline text-truncate"})[0].text           
                the_volume_id = the_volume_id.replace(" ", "")
                the_volume_id = the_volume_id.replace("\n", "")
                filename = "Hannaford"
                fullpath = "../Output/" + str(filename) + ".csv"
                #write variables per wine into csv file 
                with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                    writer = csv.writer(csv_file)
                    writer.writerow([retailer, the_brand_id, the_volume_id,the_name_id, the_price_id])
                       
            scraping_round += 1
            
        #break als er geen "next" button gevonden kan worden  
        sleep(3)
        try:
            new_element = driver.find_element(By.XPATH, '//*[@id="see-more-btn"]')
            new_element.click()
            sleep(1)

        except:
            print('kan geen volgende pagina meer vinden')
            break
        
        #update total number of wines in current view to compare with number of products in view before scrolling
        num_products_view_2 = int(len(soup.find_all(attrs={"data-category": "Coffee"})))
        print(num_products_view_2)

        #break loop if all products are scraped
        if num_products_view_2 >= total_results: 
            break
scroll_page("Hannaford")
# Out:
# nummer 1 is120
# New England Coffee Breakfast Blend
# Maxwell House Original Coffee
# Gevalia House Blend Ground Coffee
# Dunkin' Donuts Original Blend Ground Coffee
# Hannaford Breakfast Blend Single Serve
# Hannaford French Roast Coffee Single Serving
# Hannaford Colombian Blend Coffee Single
# Hannaford Donut Shop Blend Coffee Single
# Hannaford Dark Roast Coffee Single Serve Cup
# Dunkin' Donuts Original Blend K-Cups
# Hannaford Original Blend Coffee Single
# Hannaford Breakfast Blend Decaffeinated
# Hannaford Hazelnut Coffee Single Serving
# Hannaford Ground Coffee Colombian Blend
# Hannaford French Vanilla Coffee Single
# Folgers Classic Roast Ground Coffee
# Dunkin' Donuts Original Blend Ground Coffee
# Hannaford Buttery Caramel Coffee Single
# New England Coffee Breakfast Blend K-cups
# New England Coffee Hazelnut Creme
# Hannaford Morning Blend Ground Coffee
# Hannaford Dark Roast Ground Coffee
# Hannaford Toasted Coconut Coffee Single
# Green Mountain Breakfast Blend K-Cups
# New England Breakfast Blend Coffee
# Hannaford Half Caffeine Coffee Single Serving
# New England Coffee French Vanilla
# Green Mountain Dark Magic Extra Bold
# New England Coffee Butter Pecan
# Green Mountain Vermont Country
# New England Coffee Eye Opener Blend
# New England Coffee 100% Colombian
# Hannaford Coastal Blend Coffee Single
# Hannaford Brilliant Blond Single Serving
# Green Mountain Nantucket Blend
# New England Coffee Blueberry Cobbler
# Hannaford Classic Roast Ground Coffee
# Hannaford Colombian Blend Decaffeinated
# Hannaford Fair Trade Espresso Roast Coffee
# Hannaford House Blend Coffee Single Serving
# Peet's Coffee Major Dickason's Blend Dark
# New England Coffee Donut Shop
# New England Family Coffee Decaffeinated
# Dunkin' Donuts Original Blend Coffee Single
# Green Mountain Wild Mountain Blueberry
# Starbucks Pike's Place Ground Roast Coffee
# Hannaford Decaffeinated Ground
# Green Mountain Caramel Vanilla Cream
# New England Coffee Cinnamon Hazelnut
# Cafe Bustelo Brick Pack Coffee
