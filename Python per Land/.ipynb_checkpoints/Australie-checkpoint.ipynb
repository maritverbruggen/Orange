# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

driver = webdriver.Chrome(ChromeDriverManager().install())

from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from datetime import datetime
from selenium.webdriver.common.keys import Keys

import pandas as pd
import statistics
import csv
from time import sleep
import math
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Driver [C:\Users\verbr\.wdm\drivers\chromedriver\win32\102.0.5005.61\chromedriver.exe] found in cache
# C:\Users\verbr\AppData\Local\Temp/ipykernel_31856/1424107507.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
def scroll_page(retailer, url):    
    
  
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    
    driver.get(url)
    driver.maximize_window()
    sleep(10)
    #create scraping_round variable that counts the amount of times all the wines are being scraped 
    scraping_round = 1
    lengte = 0
    num_products_view_2 = 0
    #create a scroller that scrolls the_range amount of times.     
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
        
    # total number of products in current view
    num_products_view_1 = int(len(soup.find_all(attrs={"class": "ColListing--1fk1zey dlJvmX"})))
        
    #create attributes the_name_id, the_price_id, the_brand_id and the_volume_id 
    for counter in range(num_products_view_2, num_products_view_1):
        the_name_id = soup.find_all(attrs={"class": "ColListing--1fk1zey dlJvmX"})[counter].find_all(attrs={"class": "ProductCardTitle--1qhpid2 kugdfA"})[0].text
        the_name_id = the_name_id[:-24]
        print(the_name_id)
        try: 
            the_price_id = soup.find_all(attrs={"class": "ColListing--1fk1zey dlJvmX"})[counter].find_all(attrs={"class": "ProductCardPrice--bmbnub OBTaB"})[0].text
        except: 
            the_price_id = soup.find_all(attrs={"class":"ColListing--1fk1zey dlJvmX"})[counter].find_all(attrs={"class": "ProductCardPrice--bmbnub TGHdV"})[0].text
        the_brand_id = the_name_id.split()
        the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
        the_volume_id = the_name_id.split()
        the_volume_id = the_volume_id[-2] + the_volume_id[-1]
        
        filename = "IGA Australia"
        fullpath = "../Output/" + str(filename) + ".csv"
        #write variables per product into csv file 
        with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
            writer = csv.writer(csv_file)
            writer.writerow([retailer,the_brand_id, the_volume_id, the_name_id, the_price_id])

# %%
def scroll_more_pages(retailer, url):                            
                                  
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    
    driver.get(url)
    driver.maximize_window()
    sleep(5)
    try: 
        total_results = driver.find_element(By.CSS_SELECTOR, '#Instant\ Coffee').text
        total_results = total_results.replace("(", "")
        total_results = total_results.replace(")", "")
        total_results = total_results.split()
        total_results = total_results[-1]
        total_results = int(total_results)
    except:
        try: 
            total_results = driver.find_element(By.CSS_SELECTOR, '#Coffee\ Capsules\ and\ Accessories').text
            total_results = total_results.replace("(", "")
            total_results = total_results.replace(")", "")
            total_results = total_results.split()
            total_results = total_results[-1]
            total_results = int(total_results)
        except:
            try:
           
                total_results = driver.find_element(By.CSS_SELECTOR, '#Iced\ Coffee').text
                total_results = total_results.replace("(", "")
                total_results = total_results.replace(")", "")
                total_results = total_results.split()
                total_results = total_results[-1]
                total_results = int(total_results)
            except:
                print("doei")
    print(total_results)
    
        
    
    lengte = 0
    num_products_view_2 = 0
    scroll_range = 0
     
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
        
    
    
    #create attributes the_name_id, the_price_id, the_brand_id and the_volume_id
    for _ in range(20):
        
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of products in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"class": "ColListing--1fk1zey dlJvmX"})))
        print(num_products_view_1)
        
        for counter in range(num_products_view_2, num_products_view_1):
            the_name_id = soup.find_all(attrs={"class": "ColListing--1fk1zey dlJvmX"})[counter].find_all(attrs={"class": "ProductCardTitle--1qhpid2 kugdfA"})[0].text
            the_name_id = the_name_id[:-24]
            print(the_name_id)
            try: 
                the_price_id = soup.find_all(attrs={"class": "ColListing--1fk1zey dlJvmX"})[counter].find_all(attrs={"class": "ProductCardPrice--bmbnub OBTaB"})[0].text
                the_price_id = the_price_id.split()
                the_price_id = the_price_id[-1]
            except: 
                the_price_id = soup.find_all(attrs={"class":"ColListing--1fk1zey dlJvmX"})[counter].find_all(attrs={"class": "ProductCardPrice--bmbnub TGHdV"})[0].text
            print(the_price_id)
            the_brand_id = the_name_id.split()
            the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
            the_volume_id = the_name_id.split()
            the_volume_id = the_volume_id[-2] + the_volume_id[-1]
        
            filename = "IGA Australia"
            fullpath = "../Output/" + str(filename) + ".csv"
            #write variables per product into csv file 
            with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                writer = csv.writer(csv_file)
                writer.writerow([retailer,the_brand_id, the_volume_id, the_name_id, the_price_id])
            lengte+=1
            
            scroll_range += 70 
            driver.execute_script('window.scrollTo(0, ' + str(scroll_range) + ')')
        #break als er geen "next" button gevonden kan worden  
        try: 
            
            sleep(2)
            new_element = driver.find_element(By.CSS_SELECTOR, '#pageMain > div > div > div > div.CategoriesContainer--41glgw.iZUEda > div > section.Pagination--rsd5c4.eNa-DUX > nav > ul > li:nth-child(7)')
            new_element.click()
        except: 
            try:
                new_element = driver.find_element(By.CSS_SELECTOR, '#pageMain > div > div > div > div.CategoriesContainer--41glgw.iZUEda > div > section.Pagination--rsd5c4.eNa-DUX > nav > ul > li:nth-child(6) > button > span > svg')
                new_element.click()
            except: 
                try:
                    new_element = driver.find_element(By.CSS_SELECTOR, '#pageMain > div > div > div > div.CategoriesContainer--41glgw.iZUEda > div > section.Pagination--rsd5c4.eNa-DUX > nav > ul > li:nth-child(4) > button > span > svg')
                    new_element.click()
                except: 
                    print("kan geen nieuwe pagina vinden")
                    break
        
        if lengte >= total_results: 
            break 
        sleep(10)

# %%
urls = ['https://new.igashop.com.au/sm/pickup/rsid/52511/categories/coffee/coffee-beans-id-Coffee_Beans',
        'https://new.igashop.com.au/sm/pickup/rsid/52511/categories/coffee/roast-and-ground-coffee-id-Roast_and_Ground_Coffee',
        'https://new.igashop.com.au/sm/pickup/rsid/52511/categories/coffee/specialty-coffee-id-Specialty_Coffee']
urls_more = ['https://new.igashop.com.au/sm/pickup/rsid/52511/categories/coffee/instant-coffee-id-Instant_Coffee', 
             'https://new.igashop.com.au/sm/pickup/rsid/52511/categories/coffee/coffee-capsules-and-accessories-id-Coffee_Capsules_and_Accessories', 
             'https://new.igashop.com.au/sm/pickup/rsid/52511/categories/coffee/iced-coffee-id-Iced_Coffee']
for i in range(0,len(urls_more)):
    scroll_more_pages("IGA Australia", urls_more[i])
for i in range(0,len(urls)):
    scroll_page("IGA Australia", urls[i])
# Out:
# 131
# 30
# Black & Gold Coffee Granules, 100 Gram
# $2.85
# Black & Gold Coffee Powder Tin, 500 Gram
# $7.00
# Bushells Coffee, 100 Gram
# $4.19
# Bushells Coffee Turkish Style, 250 Gram
# $6.50
# Caro Coffee Caffeine Free, 150 Gram
# $6.60
# Global Cafe Decaffeinated Organic Coffee, 250 Gram
# $9.00
# Global Cafe Espresso Coffee, 250 Gram
# $9.00
# Grinders Caramel Espresso Coffee Capsules, 10 Each
# $6.00
# Grinders Decaf Capsules, 10 Each
# $7.00
# Grinders Double Espresso Coffee Capsules, 10 Each
# $6.00
# Grinders Hot Chocolate Rich & Smooth Capsules, 10 Each
# $7.00
# Grinders Smooth & Sophisticated Arabica Medium Dark Roast Coffee Capsules, 52 Gram
# $6.00
# International Roast Coffee, 200 Gram
# $8.00
# International Roast Instant Coffee, 500 Gram
# $13.00
# International Roast Instant Coffee, 100 Gram
# $6.00
# Jarrah Brazilian Cafe Latte Brazil Delight, 250 Gram
# $6.00
# Jarrah French Vanilla Latte French Style, 250 Gram
# $6.00
# L'OR Espresso Onyx Capsules, 20 Each
# $12.50
# L'OR Espresso Profondo Capsules, 20 Each
# $12.50
# L'OR Espresso Sontuoso Capsules, 10 Each
# $5.00
# Lavazza Prontissimo Classico Premium Instant Coffee, 95 Gram
# $10.00
# Lavazza Prontissimo Intenso, 95 Gram
# $10.00
# Lavazza Ristretto Coffee Capsules Intensita 11, 10 Each
# $6.00
# Lavazza Vigoroso Coffee Capsules Instensita 12, 10 Each
# $6.00
# Moccona Barista Reserve Crema, 175 Gram
# $18.00
# Moccona Barista Reserve Smooth Espresso, 175 Gram
# $18.00
# Moccona Cafe Classic Latte Sachets, 10 Each
# $4.50
# Moccona Cafe Classics Cappuccino Value Pack, 30 Each
# $10.50
# Moccona Cappuccino, 10 Each
# $4.50
# Moccona Flat White, 10 Each
# $4.50
# 30
# Moccona Freeze Dried Instant Coffee Caramel, 95 Gram
# $9.95
# Moccona Freeze Dried Instant Coffee Classic Dark Roast, 400 Gram
# $18.00
# Moccona Freeze Dried Instant Coffee Classic Dark Roast, 200 Gram
# $15.50
# Moccona Freeze Dried Instant Coffee Classic Dark Roast, 100 Gram
# $9.99
# Moccona Freeze Dried Instant Coffee Classic Decaffeinated, 100 Gram
# $12.50
# Moccona Freeze Dried Instant Coffee Classic Medium Roast, 100 Gram
# $9.99
# Moccona Freeze Dried Instant Coffee Classic Medium Roast, 50 Gram
# $6.60
# Moccona Freeze Dried Instant Coffee Classic Medium Roast, 200 Gram
# $15.50
# Moccona Freeze Dried Instant Coffee Classic Medium Roast, 400 Gram
# $18.00
# Moccona Freeze Dried Instant Coffee Classic Medium Roast (Bonus 25%), 250 Gram
# $13.00
# Moccona Freeze Dried Instant Coffee Espresso, 400 Gram
# $18.00
# Moccona Freeze Dried Instant Coffee Espresso Style, 200 Gram
# $15.50
# Moccona Freeze Dried Instant Coffee French Style, 200 Gram
# $15.50
# Moccona Freeze Dried Instant Coffee Hazelnut , 95 Gram
# $9.95
# Moccona Freeze Dried Instant Coffee Indulgence, 200 Gram
# $17.50
# Moccona Freeze Dried Instant Coffee Mocha Kenya Style, 200 Gram
# $15.50
# Moccona Freeze Dried Instant Coffee Rich, 200 Gram
# $17.50
# Moccona Intense Specialty Blends, 200 Gram
# $17.50
# Moccona Mixes Caramel Latte, 10 Each
# $4.50
# Moccona Mixes Strong Cappuccino, 10 Each
# $4.50
# Moccona Ristretto, 200 Gram
# $17.50
# Moccona Strong Cappuccino Sachets, 30 Each
# $10.50
# Moccona Vanilla Latte , 10 Each
# $4.50
# Moccona Vanilla Praline, 95 Gram
# $9.95
# Nescafe 98% Sugar Free Caramel Latte Sachets, 10 Each
# $7.00
# Nescafe 98% Sugar Free Latte Sachets, 10 Each
# $7.00
# Nescafe 98% Sugar Free Mocha Sachets, 10 Each
# $7.00
# Nescafe Black Roast, 400 Gram
# $20.00
# Nescafe Blend  43 Smooth & Creamy, 140 Gram
# $11.00
# Nescafe Blend 43, 50 Gram
# $6.00
# 30
# Nescafe Blend 43 Black Roast Instant Coffee, 100 Gram
# $9.40
# Nescafe Blend 43 Decaf, 250 Gram
# $20.00
# Nescafe Blend 43 Decaf, 100 Gram
# $11.00
# Nescafe Blend 43 Espresso, 150 Gram
# $7.50
# Nescafe Blend 43 Mild Roast, 150 Gram
# $7.50
# Nescafe Blend 43 Soluble Instant Coffee, 500 Gram
# $20.00
# Nescafe Choc Orange Mocha Coffee Sachets, 10 Each
# $7.00
# Nescafe Coffee Mixer Sachets Cappuccino, 10 Each
# $7.00
# Nescafe Coffee Mixer Sachets Cappuccino Skim, 10 Each
# $7.00
# Nescafe Coffee Mixer Sachets Cappucino Sweet, 10 Each
# $6.30
# Nescafe Coffee Mixer Sachets Caramel Latte, 10 Each
# $7.00
# Nescafe Coffee Mixer Sachets Latte Hazelnut, 10 Each
# $7.00
# Nescafe Coffee Mixer Sachets Latte Vanilla, 10 Each
# $7.00
# Nescafe Coffee Mixer Sachets Mocha, 10 Each
# $7.00
# Nescafe Coffee Mixer Sachets Strong Cappucino, 10 Each
# $7.00
# Nescafe Coffee Sachets Cappucino, 26 Each
# $11.00
# Nescafe Coffee Sachets Caramel Latte, 26 Each
# $11.00
# Nescafe Coffee Sachets Hazelnut, 26 Each
# $11.00
# Nescafe Coffee Sachets Mocha, 26 Each
# $11.00
# Nescafe Coffee Sachets Skim Cappucino, 26 Each
# $11.00
# Nescafe Coffee Sachets Strong, 26 Each
# $11.00
# Nescafe Coffee Sachets Sweet, 26 Each
# $11.00
# Nescafe Coffee Sachets Vanilla, 26 Each
# $11.00
# Nescafe Cookies & Cream, 10 Each
# $7.00
# Nescafe Decaf Cappuccino Coffee Sachets, 10 Each
# $7.00
# Nescafe Espresso, 250 Gram
# $13.50
# Nescafe Espresso Blend 43, 500 Gram
# $20.00
# Nescafe Gold Almond Latte Satchets, 6 Each
# $7.00
# Nescafe Gold Cappuccino Intense, 8 Each
# $7.00
# Nescafe Gold Cappucino, 8 Each
# $7.00
# 30
# Nescafe Gold Coconut Latte, 6 Each
# $7.00
# Nescafe Gold Coffee Mix Almond Mocha, 6 Each
# $7.00
# Nescafe Gold Creme Brulee, 8 Each
# $6.30
# Nescafe Gold Decaffeinated Instant Coffee, 100 Gram
# $13.00
# Nescafe Gold Decaffeinated Instant Coffee, 100 Gram
# $13.00
# Nescafe Gold Green And Roasted Instant Coffee, 100 Gram
# $13.00
# Nescafe Gold Green Blend Instant Coffee Jar, 100 Gram
# $13.00
# Nescafe Gold Instant Coffee Refill Soft Sachet, 320 Gram
# $22.00
# Nescafe Gold Intense Soluble Instant Coffee, 100 Gram
# $7.50
# Nescafe Gold Intense Soluble Instant Coffee, 200 Gram
# $14.00
# Nescafe Gold Mixers Double Shot Latte, 8 Each
# $7.00
# Nescafe Gold Oat Latte, 6 Each
# $7.00
# Nescafe Gold Orginal Soluble Instant Coffee, 200 Gram
# $14.00
# Nescafe Gold Orginal Soluble Instant Coffee, 100 Gram
# $7.50
# Nescafe Gold Orginal Soluble Instant Coffee, 100 Gram
# $7.50
# Nescafe Gold Rich Intensity 4, 100 Gram
# $9.50
# Nescafe Gold Short Black Espresso Instant Coffee, 100 Gram
# $13.00
# Nescafe Gold Short Black Espresso Instant Coffee, 100 Gram
# $13.00
# Nescafe Gold Smooth, 90 Gram
# $7.50
# Nescafe Gold Smooth 3, 180 Gram
# $14.00
# Nescafe Gold Tiramisu Latte, 8 Each
# $6.30
# Nescafe Latte, 10 Each
# $7.00
# Nescafe Mild Roast, 250 Gram
# $13.50
# Nescafé Blend 43 Instant Coffee, 150 Gram
# $7.50
# Nescafé Blend 43 Instant Coffee, 250 Gram
# $13.50
# Nestlé Coffee Mate Coffee Flavouring Whitener, 400 Gram
# $4.00
# Nestlé Coffee Mate Instant Coffee & Milk, 385 Gram
# $4.10
# Robert Timms Arabica Dark Roast Coffee Bag, 10 Each
# $5.95
# Robert Timms Coffee Bags, 8 Each
# $4.00
# Robert Timms Coffee Gran Instant Coffee, 500 Gram
# $20.00
# 11
# Robert Timms Italian Espresso Style Coffee Bags, 28 Each
# $9.40
# Robert Timms Mocha Kenya Style Coffee Bags, 28 Each
# $9.40
# Robert Timms Premium Full-bodied Granulated Coffee, 200 Gram
# $10.00
# Starbucks Blonde Espresso Capsules, 12 Each
# $9.00
# Starbucks Caffe Latte, 5 Each
# $5.90
# Starbucks Caffe Mocha, 5 Each
# $5.90
# Starbucks Cappuccino Capsules, 12 Each
# $9.00
# Starbucks Caramel Latte, 5 Each
# $5.90
# Starbucks Caramel Macchiato, 12 Each
# $9.00
# Starbucks Dark Roast Coffee Tin, 90 Gram
# $12.00
# Starbucks Medium Roast Coffee Tin, 90 Gram
# $12.00
# 98
# 30
# Bickford's Iced Coffee Syrup, 550 Millilitre
# $7.00
# Chicco D'oro Espresso Coffee Capsules, 12 Each
# $4.50
# Equal Low Calorie Sweetener Sachets, 100 Each
# $5.64
# Equal Sweetener Tablets, 300 Each
# $8.80
# Grinders Caramel Espresso Coffee Capsules, 10 Each
# $6.00
# Grinders Coffee Capsules Crema Caffitaly System, 10 Each
# $7.00
# Grinders Coffee Capsules Double Espresso Caffitaly System, 10 Each
# $7.00
# Grinders Coffee Capsules Espresso Nespresso System, 10 Each
# $6.00
# Grinders Decaf Capsules, 10 Each
# $7.00
# Grinders Double Espresso Coffee Capsules, 10 Each
# $6.00
# Grinders Espresso Coffee Capsules, 10 Each
# $7.00
# Grinders Hot Chocolate Rich & Smooth Capsules, 10 Each
# $7.00
# Grinders Smooth & Sophisticated Arabica Medium Dark Roast Coffee Capsules, 52 Gram
# $6.00
# Grinders Smooth Espresso Coffee Capsules, 10 Each
# $7.00
# Harris Filter Papers 10-12 Cup, 40 Each
# $2.20
# Illy Classico Espresso Capsules, 10 Each
# $6.90
# Illy Coffee Capsules Lungo Classico Classic Roast, 10 Each
# $6.90
# Illy Espresso Forte Capsules, 10 Each
# $6.90
# Illy Espresso Intenso Capsules, 10 Each
# $7.50
# L'OR Espresso Arabica Catuai Capsules, 10 Each
# $7.00
# L'OR Espresso Colombia Andes Coffee Capsules, 20 Each
# $12.50
# L'OR Espresso Colombia Coffee Capsule, 10 Each
# $5.00
# L'OR Espresso Colombia Intensity 8 , 20 Each
# $12.50
# L'OR Espresso Estremo Capsules, 10 Each
# $5.00
# L'OR Espresso Guatemala Huehuetenango Coffee Capsules, 10 Each
# $6.00
# L'OR Espresso India Coffee Capsules, 10 Each
# $6.00
# L'OR Espresso Lungo Profondo Coffee Capsules, 10 Each
# $5.00
# L'OR Espresso Onyx Capsules, 20 Each
# $12.50
# L'OR Espresso Onyx Coffee Capsules Compatible with Nespresso, 10 Each
# $5.00
# L'OR Espresso Or Absolu Coffee Capsules, 10 Each
# $5.00
# 30
# L'OR Espresso Papua Coffee Capsule, 10 Each
# $5.00
# L'OR Espresso Profondo Capsules, 20 Each
# $12.50
# L'OR Espresso Ristretto Coffee Capsules, 40 Each
# $20.00
# L'OR Espresso Ristretto Coffee Capsules Compatible with Nespresso, 10 Each
# $5.00
# L'OR Espresso Ristretto Decaf Coffee Capsule, 10 Each
# $5.00
# L'OR Espresso Sontuoso Capsules, 10 Each
# $5.00
# L'OR Espresso Supremo Coffee Capsules, 20 Each
# $12.50
# L'OR Espresso Supremo Intensity, 10 Each
# $12.50
# L'OR Espresso Supremo Intensity - Compatible with Nespresso, 10 Each
# $5.00
# L'OR Espresso Ultimo Coffee Capsules, 10 Each
# $5.00
# Lavazza A Modo Mio Delizioso Coffee Capsules, 16 Each
# $12.50
# Lavazza A Modo Mio Intenso, 16 Each
# $12.50
# Lavazza A Modo Mio Passionale Coffee Capsules, 16 Each
# $12.50
# Lavazza Armonico Coffee Capsules, 10 Each
# $6.00
# Lavazza Deciso Coffee Capsules, 10 Each
# $6.00
# Lavazza Ristretto Coffee Capsules Intensita 11, 10 Each
# $6.00
# Lavazza Vigoroso Coffee Capsules Instensita 12, 10 Each
# $6.00
# Moccona Barista Reserve Espresso Intensity 7 Capsules, 10 Each
# $4.50
# Moccona Barista Reserve Long Black Intensity, 8 Each
# $4.50
# Moccona Double Shot Latte, 10 Each
# $4.50
# Moccona Espresso Coffee Capsules, 10 Each
# $4.50
# Moccona Ristretto Coffee Capsules, 12 Each
# $4.50
# Moccona Ristretto Strong Coffee Capsules, 20 Each
# $9.00
# Nescafe Cookies & Cream, 10 Each
# $7.00
# Nescafe Dolce Gusto Café au Lait, 16 Each
# $9.00
# Nescafe Dolce Gusto Cappuccino Capsules, 16 Each
# $9.00
# Nescafe Dolce Gusto Chocoletto, 256 Gram
# $9.00
# Nescafe Dolce Gusto Coffee Capsules Ristretto Ardenza, 16 Each
# $9.00
# Nescafe Dolce Gusto Flat White Capsules, 16 Each
# $9.00
# Nescafe Farmers Origins Capsules 3 Americas Lungo, 10 Each
# $6.20
# 30
# Nescafe Farmers Origins Capsules Africas, 10 Each
# $6.20
# Nescafe Farmers Origins Capsules Brazil, 10 Each
# $6.20
# Nescafe Farmers Origins Capsules Colombia Ristretto Decaf, 10 Each
# $6.20
# Nescafe Farmers Origins Coffee Capsules India Espresso, 10 Each
# $6.20
# Nescafe Gold Almond Latte Satchets, 6 Each
# $7.00
# Nestlé Coffee Mate, 1 Kilogram
# $8.25
# Nestlé French Vanilla Coffee Mate, 10 Each
# $5.00
# Nestlé Hazelnut Coffee Mate, 10 Each
# $5.00
# Robert Timms Arabica Dark Roast Coffee Bag, 10 Each
# $5.95
# Starbucks Blonde Espresso Capsules, 12 Each
# $9.00
# Starbucks By Nespresso Blonde Espresso Roast Coffee Pods, 10 Each
# $7.50
# Starbucks By Nespresso Espresso Roast Coffee Pods, 10 Each
# $7.50
# Starbucks By Nespresso House Blend Coffee Pods, 10 Each
# $7.50
# Starbucks By Nespresso Pike Place Roast Lungo Coffee Pods, 10 Each
# $7.50
# Starbucks By Nespresso Single Origin Colombia Coffee Pods, 10 Each
# $7.50
# Starbucks By Nespresso Single Origin Sumatra Coffee Pods, 10 Each
# $7.50
# Starbucks Caffe Latte, 5 Each
# $5.90
# Starbucks Caffe Mocha, 5 Each
# $5.90
# Starbucks Caffe Verona Coffee Pods, 10 Each
# $7.50
# Starbucks Cappuccino Capsules, 12 Each
# $9.00
# Starbucks Capsules Caffe Latte, 12 Each
# $9.00
# Starbucks Capsules Decaf Espresso Roast, 10 Each
# $7.50
# Starbucks Capsules House Blend Americano, 12 Each
# $9.00
# Starbucks Capsules Lungo Pike Place, 12 Each
# $9.00
# Starbucks Caramel Latte, 5 Each
# $5.90
# Starbucks Caramel Macchiato, 12 Each
# $9.00
# Starbucks Coffee Capsules Italian Roast, 10 Each
# $7.50
# Starbucks Espresso Roast Coffee Nespresso Capsules, 30 Each
# $18.30
# Starbucks House Blend Coffee Lungo Nespresso Capsules, 30 Each
# $18.30
# Vittoria Espresso Coffee Capsules, 10 Each
# $7.00
# 8
# Vittoria Espressotoria Espresso Coffee Capsules, 12 Each
# $5.00
# Vittoria Espressotoria Italian Coffee Capsules, 12 Each
# $5.00
# Vittoria Espressotoria Mountain Grown Coffee Capsules, 12 Each
# $5.00
# Vittoria Espressotoria Oro Coffee Capsules, 12 Each
# $5.00
# Vittoria Italian Blend Coffee Capsules, 10 Each
# $6.00
# Vittoria Mountain Grown Coffee Capsules, 10 Each
# $7.00
# Vittoria Organic Espressotoria Compatible Coffee Capsules, 12 Each
# $8.40
# Vittoria Oro Coffee Capsules, 10 Each
# $7.00
# 48
# 30
# Barista Bros Double Espresso Iced Coffee Flavoured Milk, 700 Millilitre
# $3.60
# Barista Bros Double Expresso, 500 Millilitre
# $3.20
# Barista Bros Iced Coffee Flavoured Milk, 500 Millilitre
# $3.20
# Bickford's Iced Coffee Almond, 500 Millilitre
# $4.00
# Bickford's Iced Coffee Classic, 500 Millilitre
# $4.00
# Bickford's Iced Coffee Extra Shot Flavoured Milk, 500 Millilitre
# $4.00
# Bickford's Iced Coffee Syrup, 500 Millilitre
# $6.00
# Boss Black Coffee, 237 Millilitre
# $3.75
# Boss Iced Latte, 237 Millilitre
# $3.75
# Califa Farms Oat Barista Blend, 1 Litre
# $4.90
# Califia Farms Cold Brew Mocha, 310 Millilitre
# $3.30
# Califia Farms Double Espresso Cold Brew Coffee With Almond, 750 Millilitre
# $4.15
# Califia Farms Mocha Cold Brew With Almond, 750 Millilitre
# $4.15
# Dare Double Espresso Iced Coffee, 500 Millilitre
# $3.60
# Dare Double Espresso Iced Coffee, 500 Millilitre
# $3.60
# Dare Double Espresso Iced Coffee, 750 Millilitre
# $3.40
# Dare Double Espresso No Added Sugar, 500 Millilitre
# $3.60
# Dare Espresso Iced Coffee, 500 Millilitre
# $3.60
# Dare Espresso Iced Coffee, 750 Millilitre
# $3.40
# Dare Iced Coffee Caramel Latte, 500 Millilitre
# $3.60
# Dare Iced Coffee Double Espresso, 500 Millilitre
# $3.60
# Dare Iced Coffee Espresso Robusta & Arabica, 750 Millilitre
# $3.40
# Dare Mocha, 750 Millilitre
# $4.40
# Dare Mocha Iced Coffee, 500 Millilitre
# $3.60
# Dare Mocha Iced Coffee, 500 Millilitre
# $3.60
# Dare Peanut Butter Latte, 500 Millilitre
# $3.60
# Dare Triple Espresso, 500 Millilitre
# $3.60
# Ice Break Bold Espresso, 500 Millilitre
# $3.40
# Ice Break Bold Espresso, 500 Millilitre
# $3.40
# Ice Break Bold Espresso Coffee, 750 Millilitre
# $3.80
# 18
# Ice Break Iced Coffee Bold Espresso, 750 Millilitre
# $3.80
# Ice Break Iced Coffee Regular Strength, 750 Millilitre
# $3.80
# Ice Break Iced Coffee Regular Strength, 500 Millilitre
# $3.50
# Ice Break Iced Coffee Triple Shot, 500 Millilitre
# $3.50
# Ice Break Iced Coffee Triple Shot, 750 Millilitre
# $4.25
# Nescafe Nativ Cascara Classic, 330 Millilitre
# $4.50
# Nescafe Nativ Cascara Lemon Myrtle & Pepperberry, 330 Millilitre
# $4.50
# Nescafe Nativ Nascara Kakadu Plum, 330 Millilitre
# $4.50
# Nescafe Ready To Drink Espresso, 250 Millilitre
# $3.50
# Nescafe Ready to Drink Flat White, 250 Millilitre
# $3.50
# Nescafe Ready to Drink Mocha, 250 Millilitre
# $3.50
# OAK Iced Coffee, 600 Millilitre
# $3.25
# OAK Iced Coffee, 3 Each
# $4.50
# OAK Iced Coffee, 750 Millilitre
# $3.85
# Oak Iced Coffee Flavoured Milk, 2 Litre
# $4.50
# Pauls Zymil Lactose Free Coffee Flavoured Milk, 400 Millilitre
# $3.65
# Suntory Boss Coffee Iced Vanilla Latte, 237 Millilitre
# $3.75
# Vitasoy Almond Double Espresso, 330 Millilitre
# $3.65
# Grinders Coffee Beans Espresso, 1 Kilogram
# Grinders Coffee Roasters Deep & Full Bodied Rich Espresso Coffee Beans, 1 Kilogram
# Grinders Coffee Roasters Organic Coffee Beans, 1 Kilogram
# Grinders Crema, 1 Kilogram
# Harris Coffee Beans Organic, 1 Kilogram
# Harris Coffee Beans Smooth, 1 Kilogram
# Harris Coffee Beans Strong, 1 Kilogram
# Harris Very Strong Coffee Beans, 1 Kilogram
# Lavazza Espresso Barista Gran Crema Coffee Beans, 1 Kilogram
# Lavazza Espresso Barista Intenso Coffee Beans, 1 Kilogram
# Lavazza Espresso Barista Perfetto Coffee Beans, 1 Kilogram
# Lavazza Qualita Oro Coffee Beans, 1 Kilogram
# Lavazza Qualita Rossa Beans, 1 Kilogram
# Lavazza Tierra Bio-organic Coffee Beans, 500 Gram
# Moccona Coffee Beans Dark Roast , 1 Kilogram
# Moccona Wholebean Barista Rich Espresso, 175 Gram
# Starbucks Espresso Dark Roast Beans , 200 Gram
# Starbucks Pike Place Medium Roast Coffee Beans, 200 Gram
# Vittoria Coffee Bean Mountain Grown, 1 Kilogram
# Vittoria Espresso Beans, 500 Gram
# Vittoria Espresso Coffee Beans, 200 Gram
# Vittoria Espresso Coffee Beans, 1 Kilogram
# Vittoria Espresso Ground Coffee, 1 Kilogram
# Vittoria Ground Oro Coffee, 1 Kilogram
# Vittoria Italian Blend Coffee Beans, 1 Kilogram
# Aurora Coffee Ground Italian, 1 Kilogram
# Caffe Aurora Ground Coffee Italian Style, 250 Gram
# Delta Chicco D'oro Ground Coffee, 200 Gram
# Grinders Coffee Roasters Espresso Ground Coffee, 200 Gram
# Grinders Ground Coffee Crema, 200 Gram
# Grinders Ground Coffee Espresso, 200 Gram
# Harris Coffee Ground Smooth, 1 Kilogram
# Harris Coffee Ground Smooth, 200 Gram
# Harris Coffee Ground Strong, 1 Kilogram
# Harris Coffee Ground Very Strong, 200 Gram
# Harris Organic Ground Coffee, 200 Gram
# Harris Strong Ground Coffee, 200 Gram
# Lavazza Coffee Groud Qualita Rosa, 250 Gram
# Lavazza Crema E Gusto Classico Ground Coffee, 250 Gram
# Lavazza Espresso Italiano Classico Ground Coffee, 250 Gram
# Lavazza Ground Decaf Coffee, 250 Gram
# Lavazza Qualita Oro Ground Coffee, 500 Gram
# Lavazza Qualita Oro Ground Coffee, 1 Kilogram
# Lavazza Qualita Oro Ground Coffee, 250 Gram
# Lavazza Qualita Rossa Ground Coffee, 1 Kilogram
# Oxfam Fair Organic Fair Trade Ground Africa Blend Coffee, 250 Gram
# Robert Timms Coffee Bags Mocha Kenya Pack, 8 Each
# Starbucks Coffee Ground House Blend Medium Roast, 200 Gram
# Vittoria Decaffeinated Ground Coffee Espresso, 200 Gram
# Vittoria Espresso Ground Coffee, 200 Gram
# Vittoria Espresso Ground Coffee, 500 Gram
# Vittoria Italian Blend Ground Coffee, 200 Gram
# Vittoria Mountain Grown Ground Coffee, 1 Kilogram
# Vittoria Mountain Grown Ground Coffee, 200 Gram
# Nestlé Coffee Mate Instant Coffee & Milk, 385 Gram
# Tetley Chai Latte Classic Sachets, 8 Each

# %%
from bs4 import BeautifulSoup
res = driver.page_source.encode('utf-8')
soup = BeautifulSoup(res, "html.parser")

# %%
driver.get("https://www.woolworths.com.au/shop/browse/drinks/coffee")
driver.maximize_window()
sleep(10)

# %%
def scroll_page(retailer):    
    
    #call get_url function to get the correct url linked to the Region that is going to be scraped    
    sleep(1)
    
    res = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(res, "html.parser")
    
    
    #create scraping_round variable that counts the amount of times all the wines are being scraped 
    scraping_round = 1
    lengte = 0
    num_products_view_2 = 0
    number = 0
    #create a scroller that scrolls the_range amount of times.     
    for _ in range(20):
        res = driver.page_source.encode('utf-8')
        soup = BeautifulSoup(res, "html.parser")
        
        # total number of wines in current view
        num_products_view_1 = int(len(soup.find_all(attrs={"class": "shelfProductTile-information"})))
        print(num_products_view_1)
        #create attributes the_name_id, the_price_id, the_reviews_id and the_rating id
        for counter in range(num_products_view_2, num_products_view_1):
            the_name_id = soup.find_all(attrs={"class": "shelfProductTile-information"})[counter].find_all(attrs={"class": "shelfProductTile-description"})[0].text
            try: 
                the_price_id = soup.find_all(attrs={"class": "shelfProductTile-information"})[counter].find_all(attrs={"class": "price-was price--large ng-star-inserted"})[0].text
            except:
                try:
                    the_price_id = soup.find_all(attrs={"class": "shelfProductTile-information"})[counter].find_all(attrs={"class": "price price--large ng-star-inserted"})[0].text
                except: 
                    the_price_id = "Out of Stock, No Price Available"
            print(the_name_id)
            the_brand_id = the_name_id.split()
            the_brand_id = the_brand_id[0] + " " + the_brand_id[1]
            the_volume_id = the_name_id.split()
            for i in range(0,len(the_volume_id)):
                if 'ack' in the_volume_id[i] and any(ch.isdigit() for ch in the_volume_id[i-1]):
                    the_volume = the_volume_id[i-1] + " " + "Pack"
                elif 'g' in the_volume_id[i] or 'kg' in the_volume_id[i]:
                    the_volume = the_volume_id[i]
                else: 
                    next 
            for i in range(0,len(the_volume_id)-1): 
                if 'ack' in the_volume_id[i] and any(ch.isdigit() for ch in the_volume_id[i+1]):
                        the_volume = the_volume_id[i+1] + " " + "Pack"
                else: 
                    next 
            print(the_volume)
                
            filename = "Woolworths"
            fullpath = "../Output/" + str(filename) + ".csv"
        
            with open(fullpath, mode='a', newline='', encoding='utf-8') as csv_file:
                writer = csv.writer(csv_file)
                writer.writerow([retailer, the_brand_id, the_volume,the_name_id, the_price_id])

            number +=1
        #break als er geen "next" button gevonden kan worden  
        sleep(3)
        try:
            new_element = driver.find_element(By.CSS_SELECTOR, '#search-content > div > shared-paging > div > div.paging-section > a.paging-next.ng-star-inserted > span.next-marker')
            new_element.click()
            sleep(25)

        except:
            print('kan niet vinden')
            print(number)
            break
            
scroll_page("Woolworths")
# Out:
# 44
# Moccona Freeze Dried Instant Coffee Classic Medium Roast 200g
# 200g
# Grinders Rich Espresso Beans Rainforest Alliance Certified 1kg
# 1kg
# Nescafe Blend 43 Instant Coffee Jar 150g
# 150g
# Grinders Rainforest Alliance Certified Coffee Beans Espresso 1kg
# 1kg
# Nescafe Blend 43 Instant Coffee Tin 500g
# 500g
# Vittoria Freeze Dried Instant Coffee Mountain Grown 100g
# 100g
# Moccona Freeze Dried Instant Coffee Classic Medium Roast 400g
# 400g
# Will & Co Sweet Ride Nespresso Compatible Coffee Capsules 10 Pack
# 10 Pack
# Moccona Freeze Dried Instant Coffee Classic Medium Roast 100g
# 100g
# Moccona Freeze Dried Instant Coffee Classic Dark Roast 200g
# 200g
# Woolworths Freeze Dried Coffee Original 100g
# 100g
# Nescafe Coffee Sachets Cappuccino 10 Pack
# 10 Pack
# Moccona Coffee Sachets Caramel Latte 10 Pack
# 10 Pack
# Vittoria Freeze Dried Instant Coffee Italian 100g
# 100g
# Nescafe Gold Orginal Soluble Instant Coffee 200g
# 200g
# Vittoria Freeze Dried Instant Coffee Latte 100g
# 100g
# Nescafe Coffee Sachets Caramel Latte 10 Pack
# 10 Pack
# Vittoria Freeze Dried Instant Coffee Classic 100g
# 100g
# Nescafe Blend 43 Instant Coffee Jar 300g
# 300g
# Will & Co Goofy Nespresso Compatible Coffee Capsules 10 Pack
# 10 Pack
